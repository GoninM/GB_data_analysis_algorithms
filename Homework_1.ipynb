# %% [markdown]
# **Алгоритмы анализа данных**
#
# **Урок 1. Алгоритм линейной регрессии. Градиентный спуск**
#
# Домашнее задание №1.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([[ 1,  1],
              [ 1,  1],
              [ 1,  2],
              [ 1,  5],
              [ 1,  3],
              [ 1,  0],
              [ 1,  5],
              [ 1, 10],
              [ 1,  1],
              [ 1,  2]])

# %%
y = [45, 55, 50, 55, 60, 35, 75, 80, 50, 60]

# %%
def calc_mae(y, y_pred):
    err = np.mean(np.abs(y - y_pred))
    return err

def calc_mse(y, y_pred):
    err = np.mean((y - y_pred)**2)
    return err

# %% [markdown]
# 1. Подберите скорость обучения (eta) и количество итераций

# %%
eta_list = np.arange(0.0001, 0.05, 0.005).round(4).tolist()
eta_list
# Out:
# [0.0001,
#  0.0051,
#  0.0101,
#  0.0151,
#  0.0201,
#  0.0251,
#  0.0301,
#  0.0351,
#  0.0401,
#  0.0451]

# %%
iter_list = [i for i in range(100, 6000, 1000)]
iter_list
# Out:
# [100, 1100, 2100, 3100, 4100, 5100]

# %%
def check_params(n_iter: int, eta: float, W) -> tuple:
    errors = []
    eta_list = []

    list_size = 10
    step = n_iter/list_size
    print(W, n_iter, eta)
    
    for i in range(n_iter):
        y_pred = np.dot(X, W)
        err = calc_mse(y, y_pred)

        for k in range(W.shape[0]):
            W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
        if i % step == 0:
            errors.append(err)
            eta_list.append(eta)      
            eta /= 1.1
            print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 3)}')

    return errors, eta_list

# %%
# # начальное условие
# n = X.shape[0]

# # eta = 5e-2
# # n_iter = 1000 #100
# result = {}

# W = np.array([1, 0.5])

# print(f'Number of objects = {n} \
#        \nLearning rate = {eta} \
#        \nInitial weights = {W} \n')

# for n_iter in iter_list:
#     for eta in eta_list:
#         print(f'Params: {n_iter} {eta}')
#         result[(n_iter, eta)] = (check_params(n_iter, eta, W.copy()))
# #         errors, eta_list = check_params(n_iter, eta, W.copy())
#         print('\n\n')

# %%
fig, ax = plt.subplots(nrows=len(iter_list), ncols=len(eta_list), figsize=(40, 40))

for i in range(len(iter_list)):
    for j in range(len(eta_list)):
        x, y = check_params(iter_list[i], eta_list[j], W.copy())
        
        ax[i,j].plot(x, y)
        ax[i,j].set_title(f'iter:{iter_list[i]}, eta:{eta_list[j]}')

plt.show()
# Out:
# [1.  0.5] 100 0.0001
# Iteration #0: W_new = [0.9995061  0.49771681], MSE = 8.106
# Iteration #10: W_new = [0.99508339 0.47732994], MSE = 7.62
# Iteration #20: W_new = [0.99116533 0.45935923], MSE = 7.205
# Iteration #30: W_new = [0.98768578 0.44347385], MSE = 6.848
# Iteration #40: W_new = [0.98458881 0.42939599], MSE = 6.539
# Iteration #50: W_new = [0.98182683 0.41689106], MSE = 6.271
# Iteration #60: W_new = [0.97935915 0.40575989], MSE = 6.038
# Iteration #70: W_new = [0.97715082 0.39583258], MSE = 5.834
# Iteration #80: W_new = [0.97517165 0.3869635 ], MSE = 5.655
# Iteration #90: W_new = [0.9733955  0.37902731], MSE = 5.497
# [1.  0.5] 100 0.0051
# Iteration #0: W_new = [0.97450069 0.3827019 ], MSE = 8.25
# Iteration #10: W_new = [ 0.85657553 -0.06055346], MSE = 0.553
# Iteration #20: W_new = [ 0.8115653  -0.12802936], MSE = 0.319
# Iteration #30: W_new = [ 0.78120007 -0.1371337 ], MSE = 0.289
# Iteration #40: W_new = [ 0.75618453 -0.13588547], MSE = 0.271
# Iteration #50: W_new = [ 0.73448685 -0.13279913], MSE = 0.255
# Iteration #60: W_new = [ 0.71538965 -0.12958344], MSE = 0.242
# Iteration #70: W_new = [ 0.69848525 -0.12659855], MSE = 0.231
# Iteration #80: W_new = [ 0.68347333 -0.12390526], MSE = 0.221
# Iteration #90: W_new = [ 0.67011007 -0.12149337], MSE = 0.212
# [1.  0.5] 100 0.0101
# Iteration #0: W_new = [0.94956963 0.26789199], MSE = 8.234
# Iteration #10: W_new = [ 0.80393138 -0.13620489], MSE = 0.308
# Iteration #20: W_new = [ 0.7436491  -0.13399068], MSE = 0.262
# Iteration #30: W_new = [ 0.69396716 -0.12525014], MSE = 0.228
# Iteration #40: W_new = [ 0.65175106 -0.11760683], MSE = 0.2
# Iteration #50: W_new = [ 0.61562934 -0.11105744], MSE = 0.178
# Iteration #60: W_new = [ 0.58454974 -0.10542169], MSE = 0.161
# Iteration #70: W_new = [ 0.55767385 -0.10054817], MSE = 0.146
# Iteration #80: W_new = [ 0.53432691 -0.09631457], MSE = 0.134
# Iteration #90: W_new = [ 0.51396137 -0.09262159], MSE = 0.124
# [1.  0.5] 100 0.0151
# Iteration #0: W_new = [0.92470616 0.15326844], MSE = 8.218
# Iteration #10: W_new = [ 0.76670982 -0.13743984], MSE = 0.278
# Iteration #20: W_new = [ 0.68452181 -0.12298263], MSE = 0.221
# Iteration #30: W_new = [ 0.61764189 -0.11085639], MSE = 0.179
# Iteration #40: W_new = [ 0.56261738 -0.10087855], MSE = 0.148
# Iteration #50: W_new = [ 0.51693176 -0.09259416], MSE = 0.124
# Iteration #60: W_new = [ 0.4786845  -0.08565861], MSE = 0.106
# Iteration #70: W_new = [ 0.44642269 -0.07980843], MSE = 0.092
# Iteration #80: W_new = [ 0.41902305 -0.07483993], MSE = 0.081
# Iteration #90: W_new = [ 0.39560789 -0.07059395], MSE = 0.072
# [1.  0.5] 100 0.0201
# Iteration #0: W_new = [0.89991029 0.03883126], MSE = 8.202
# Iteration #10: W_new = [ 0.73270189 -0.1311476 ], MSE = 0.254
# Iteration #20: W_new = [ 0.63054528 -0.11263016], MSE = 0.186
# Iteration #30: W_new = [ 0.55033515 -0.09808529], MSE = 0.141
# Iteration #40: W_new = [ 0.48650477 -0.08651064], MSE = 0.109
# Iteration #50: W_new = [ 0.43508643 -0.07718672], MSE = 0.087
# Iteration #60: W_new = [ 0.39320579 -0.06959231], MSE = 0.07
# Iteration #70: W_new = [ 0.35874928 -0.06334415], MSE = 0.058
# Iteration #80: W_new = [ 0.33014106 -0.05815649], MSE = 0.049
# Iteration #90: W_new = [ 0.3061909 -0.0538135], MSE = 0.042
# [1.  0.5] 100 0.0251
# Iteration #0: W_new = [ 0.875182   -0.07541956], MSE = 8.186
# Iteration #10: W_new = [ 0.7004857  -0.12474671], MSE = 0.231
# Iteration #20: W_new = [ 0.58127443 -0.1031296 ], MSE = 0.157
# Iteration #30: W_new = [ 0.49105802 -0.08677024], MSE = 0.111
# Iteration #40: W_new = [ 0.42162535 -0.0741797 ], MSE = 0.08
# Iteration #50: W_new = [ 0.36736587 -0.06434058], MSE = 0.06
# Iteration #60: W_new = [ 0.32437192 -0.05654429], MSE = 0.046
# Iteration #70: W_new = [ 0.28987315 -0.05028847], MSE = 0.036
# Iteration #80: W_new = [ 0.26187298 -0.04521107], MSE = 0.029
# Iteration #90: W_new = [ 0.23891034 -0.04104715], MSE = 0.024
# [1.  0.5] 100 0.0301
# Iteration #0: W_new = [ 0.8505213  -0.18948403], MSE = 8.17
# Iteration #10: W_new = [ 0.66991496 -0.11863713], MSE = 0.21
# Iteration #20: W_new = [ 0.53634193 -0.09441572], MSE = 0.132
# Iteration #30: W_new = [ 0.43892856 -0.07675131], MSE = 0.087
# Iteration #40: W_new = [ 0.36643146 -0.06360508], MSE = 0.059
# Iteration #50: W_new = [ 0.31147648 -0.05363984], MSE = 0.042
# Iteration #60: W_new = [ 0.26911833 -0.04595884], MSE = 0.031
# Iteration #70: W_new = [ 0.23597165 -0.0399482 ], MSE = 0.023
# Iteration #80: W_new = [ 0.20967451 -0.03517962], MSE = 0.018
# Iteration #90: W_new = [ 0.18854975 -0.03134897], MSE = 0.014
# [1.  0.5] 100 0.0351
# Iteration #0: W_new = [ 0.8259282  -0.30336212], MSE = 8.154
# Iteration #10: W_new = [ 0.64091969 -0.11281323], MSE = 0.191
# Iteration #20: W_new = [ 0.49540804 -0.08642693], MSE = 0.111
# Iteration #30: W_new = [ 0.3931588  -0.06788561], MSE = 0.068
# Iteration #40: W_new = [ 0.319584   -0.05454395], MSE = 0.044
# Iteration #50: W_new = [ 0.26549074 -0.04473497], MSE = 0.029
# Iteration #60: W_new = [ 0.22493681 -0.03738115], MSE = 0.02
# Iteration #70: W_new = [ 0.19399036 -0.03176948], MSE = 0.014
# Iteration #80: W_new = [ 0.16999293 -0.02741792], MSE = 0.011
# Iteration #90: W_new = [ 0.15111089 -0.02399395], MSE = 0.008
# [1.  0.5] 100 0.0401
# Iteration #0: W_new = [ 0.80140268 -0.41705386], MSE = 8.138
# Iteration #10: W_new = [ 0.61343361 -0.10726378], MSE = 0.174
# Iteration #20: W_new = [ 0.45815834 -0.07910621], MSE = 0.094
# Iteration #30: W_new = [ 0.35304502 -0.06004553], MSE = 0.053
# Iteration #40: W_new = [ 0.279925   -0.04678635], MSE = 0.032
# Iteration #50: W_new = [ 0.22778978 -0.03733243], MSE = 0.02
# Iteration #60: W_new = [ 0.18977594 -0.0304392 ], MSE = 0.013
# Iteration #70: W_new = [ 0.16149051 -0.02531008], MSE = 0.009
# Iteration #80: W_new = [ 0.14005293 -0.0214227 ], MSE = 0.006
# Iteration #90: W_new = [ 0.12353183 -0.01842686], MSE = 0.005
# [1.  0.5] 100 0.0451
# Iteration #0: W_new = [ 0.77694475 -0.53055923], MSE = 8.122
# Iteration #10: W_new = [ 0.58737527 -0.10207552], MSE = 0.158
# Iteration #20: W_new = [ 0.42430203 -0.07240084], MSE = 0.079
# Iteration #30: W_new = [ 0.31795905 -0.05311718], MSE = 0.042
# Iteration #40: W_new = [ 0.24645359 -0.04015076], MSE = 0.024
# Iteration #50: W_new = [ 0.19701486 -0.03118581], MSE = 0.014
# Iteration #60: W_new = [ 0.16195908 -0.02482899], MSE = 0.009
# Iteration #70: W_new = [ 0.13652641 -0.02021716], MSE = 0.006
# Iteration #80: W_new = [ 0.1176883  -0.01680116], MSE = 0.004
# Iteration #90: W_new = [ 0.10346966 -0.01422283], MSE = 0.003
# [1.  0.5] 1100 0.0001
# Iteration #0: W_new = [0.9995061  0.49771681], MSE = 8.106
# Iteration #110: W_new = [0.95675133 0.30578831], MSE = 4.176
# Iteration #220: W_new = [0.92704982 0.18151211], MSE = 2.355
# Iteration #330: W_new = [0.90555006 0.09858999], MSE = 1.456
# Iteration #440: W_new = [0.88940745 0.04173822], MSE = 0.986
# Iteration #550: W_new = [0.87689512 0.00179097], MSE = 0.727
# Iteration #660: W_new = [ 0.86692957 -0.02690956], MSE = 0.578
# Iteration #770: W_new = [ 0.85880932 -0.04794954], MSE = 0.487
# Iteration #880: W_new = [ 0.85206638 -0.06365822], MSE = 0.43
# Iteration #990: W_new = [ 0.84637945 -0.07558277], MSE = 0.392
# [1.  0.5] 1100 0.0051
# Iteration #0: W_new = [0.97450069 0.3827019 ], MSE = 8.25
# Iteration #110: W_new = [ 0.54985037 -0.09969556], MSE = 0.144
# Iteration #220: W_new = [ 0.35998749 -0.06526686], MSE = 0.061
# Iteration #330: W_new = [ 0.24496094 -0.04440857], MSE = 0.028
# Iteration #440: W_new = [ 0.17264198 -0.03129464], MSE = 0.014
# Iteration #550: W_new = [ 0.12561727 -0.02276743], MSE = 0.007
# Iteration #660: W_new = [ 0.09409042 -0.01705053], MSE = 0.004
# Iteration #770: W_new = [ 0.07235844 -0.01310977], MSE = 0.002
# Iteration #880: W_new = [ 0.05699535 -0.01032391], MSE = 0.002
# Iteration #990: W_new = [ 0.04588274 -0.00830881], MSE = 0.001
# [1.  0.5] 1100 0.0101
# Iteration #0: W_new = [0.94956963 0.26789199], MSE = 8.234
# Iteration #110: W_new = [ 0.34821057 -0.06256524], MSE = 0.057
# Iteration #220: W_new = [ 0.15237746 -0.02705392], MSE = 0.011
# Iteration #330: W_new = [ 0.0729936  -0.01265888], MSE = 0.002
# Iteration #440: W_new = [ 0.03833974 -0.00637494], MSE = 0.001
# Iteration #550: W_new = [ 0.02216004 -0.003441  ], MSE = 0.0
# Iteration #660: W_new = [ 0.01413045 -0.00198496], MSE = 0.0
# Iteration #770: W_new = [ 0.00991857 -0.0012212 ], MSE = 0.0
# Iteration #880: W_new = [ 0.00759527 -0.0007999 ], MSE = 0.0
# Iteration #990: W_new = [ 0.00625383 -0.00055665], MSE = 0.0
# [1.  0.5] 1100 0.0151
# Iteration #0: W_new = [0.92470616 0.15326844], MSE = 8.218
# Iteration #110: W_new = [ 0.22283231 -0.03926376], MSE = 0.022
# Iteration #220: W_new = [ 0.06859796 -0.01129574], MSE = 0.002
# Iteration #330: W_new = [ 0.02692622 -0.00373921], MSE = 0.0
# Iteration #440: W_new = [ 0.01433589 -0.00145615], MSE = 0.0
# Iteration #550: W_new = [ 0.01012622 -0.00069279], MSE = 0.0
# Iteration #660: W_new = [ 0.00858316 -0.00041298], MSE = 0.0
# Iteration #770: W_new = [ 0.00796835 -0.0003015 ], MSE = 0.0
# Iteration #880: W_new = [ 0.00770413 -0.00025359], MSE = 0.0
# Iteration #990: W_new = [ 0.00758251 -0.00023153], MSE = 0.0
# [1.  0.5] 1100 0.0201
# Iteration #0: W_new = [0.89991029 0.03883126], MSE = 8.202
# Iteration #110: W_new = [ 0.14554894 -0.02468356], MSE = 0.009
# Iteration #220: W_new = [ 0.03620623 -0.00485594], MSE = 0.0
# Iteration #330: W_new = [ 0.01658853 -0.00129858], MSE = 0.0
# Iteration #440: W_new = [ 0.01249906 -0.00055701], MSE = 0.0
# Iteration #550: W_new = [ 0.0115224  -0.00037991], MSE = 0.0
# Iteration #660: W_new = [ 0.01125855 -0.00033206], MSE = 0.0
# Iteration #770: W_new = [ 0.01117884 -0.00031761], MSE = 0.0
# Iteration #880: W_new = [ 0.01115219 -0.00031278], MSE = 0.0
# Iteration #990: W_new = [ 0.01114242 -0.00031101], MSE = 0.0
# [1.  0.5] 1100 0.0251
# Iteration #0: W_new = [ 0.875182   -0.07541956], MSE = 8.186
# Iteration #110: W_new = [ 0.0985382  -0.01559282], MSE = 0.003
# Iteration #220: W_new = [ 0.02506434 -0.00226947], MSE = 0.0
# Iteration #330: W_new = [ 0.01634165 -0.00068775], MSE = 0.0
# Iteration #440: W_new = [ 0.01509082 -0.00046093], MSE = 0.0
# Iteration #550: W_new = [ 0.01487799 -0.00042233], MSE = 0.0
# Iteration #660: W_new = [ 0.0148357  -0.00041467], MSE = 0.0
# Iteration #770: W_new = [ 0.01482603 -0.00041291], MSE = 0.0
# Iteration #880: W_new = [ 0.01482352 -0.00041246], MSE = 0.0
# Iteration #990: W_new = [ 0.01482279 -0.00041233], MSE = 0.0
# [1.  0.5] 1100 0.0301
# Iteration #0: W_new = [ 0.8505213  -0.18948403], MSE = 8.17
# Iteration #110: W_new = [ 0.07054488 -0.00995061], MSE = 0.001
# Iteration #220: W_new = [ 0.0226784  -0.00127076], MSE = 0.0
# Iteration #330: W_new = [ 0.01893072 -0.00059118], MSE = 0.0
# Iteration #440: W_new = [ 0.01856208 -0.00052433], MSE = 0.0
# Iteration #550: W_new = [ 0.0185175  -0.00051624], MSE = 0.0
# Iteration #660: W_new = [ 0.01851099 -0.00051507], MSE = 0.0
# Iteration #770: W_new = [ 0.01850987 -0.00051486], MSE = 0.0
# Iteration #880: W_new = [ 0.01850964 -0.00051482], MSE = 0.0
# Iteration #990: W_new = [ 0.01850959 -0.00051481], MSE = 0.0
# [1.  0.5] 1100 0.0351
# Iteration #0: W_new = [ 0.8259282  -0.30336212], MSE = 8.154
# Iteration #110: W_new = [ 0.05447486 -0.0064705 ], MSE = 0.001
# Iteration #220: W_new = [ 0.0238874  -0.00092393], MSE = 0.0
# Iteration #330: W_new = [ 0.0223129  -0.00063842], MSE = 0.0
# Iteration #440: W_new = [ 0.02220695 -0.00061921], MSE = 0.0
# Iteration #550: W_new = [ 0.02219786 -0.00061756], MSE = 0.0
# Iteration #660: W_new = [ 0.02219689 -0.00061739], MSE = 0.0
# Iteration #770: W_new = [ 0.02219676 -0.00061736], MSE = 0.0
# Iteration #880: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #990: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# [1.  0.5] 1100 0.0401
# Iteration #0: W_new = [ 0.80140268 -0.41705386], MSE = 8.138
# Iteration #110: W_new = [ 0.0458655  -0.00434326], MSE = 0.0
# Iteration #220: W_new = [ 0.02656702 -0.00084378], MSE = 0.0
# Iteration #330: W_new = [ 0.02591578 -0.00072569], MSE = 0.0
# Iteration #440: W_new = [ 0.02588588 -0.00072027], MSE = 0.0
# Iteration #550: W_new = [ 0.02588406 -0.00071994], MSE = 0.0
# Iteration #660: W_new = [ 0.02588392 -0.00071991], MSE = 0.0
# Iteration #770: W_new = [ 0.02588391 -0.00071991], MSE = 0.0
# Iteration #880: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #990: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# [1.  0.5] 1100 0.0451
# Iteration #0: W_new = [ 0.77694475 -0.53055923], MSE = 8.122
# Iteration #110: W_new = [ 0.04191509 -0.00306086], MSE = 0.0
# Iteration #220: W_new = [ 0.02984606 -0.00087233], MSE = 0.0
# Iteration #330: W_new = [ 0.02957977 -0.00082404], MSE = 0.0
# Iteration #440: W_new = [ 0.02957145 -0.00082253], MSE = 0.0
# Iteration #550: W_new = [ 0.02957109 -0.00082247], MSE = 0.0
# Iteration #660: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #770: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #880: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #990: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# [1.  0.5] 2100 0.0001
# Iteration #0: W_new = [0.9995061  0.49771681], MSE = 8.106
# Iteration #210: W_new = [0.92704698 0.18149663], MSE = 2.356
# Iteration #420: W_new = [0.88634736 0.03159094], MSE = 0.916
# Iteration #630: W_new = [ 0.86064281 -0.04341469], MSE = 0.505
# Iteration #840: W_new = [ 0.84266205 -0.08272201], MSE = 0.372
# Iteration #1050: W_new = [ 0.82903658 -0.10412778], MSE = 0.322
# Iteration #1260: W_new = [ 0.81810014 -0.11614088], MSE = 0.299
# Iteration #1470: W_new = [ 0.80897165 -0.12302535], MSE = 0.287
# Iteration #1680: W_new = [ 0.8011521 -0.127011 ], MSE = 0.279
# Iteration #1890: W_new = [ 0.79433846 -0.12930951], MSE = 0.273
# [1.  0.5] 2100 0.0051
# Iteration #0: W_new = [0.97450069 0.3827019 ], MSE = 8.25
# Iteration #210: W_new = [ 0.35995808 -0.06526153], MSE = 0.062
# Iteration #420: W_new = [ 0.16036633 -0.02906864], MSE = 0.012
# Iteration #630: W_new = [ 0.07692512 -0.01393786], MSE = 0.003
# Iteration #840: W_new = [ 0.03947045 -0.00714604], MSE = 0.001
# Iteration #1050: W_new = [ 0.02153659 -0.00389401], MSE = 0.0
# Iteration #1260: W_new = [ 0.01243111 -0.00224287], MSE = 0.0
# Iteration #1470: W_new = [ 0.00755521 -0.0013587 ], MSE = 0.0
# Iteration #1680: W_new = [ 0.00481487 -0.00086178], MSE = 0.0
# Iteration #1890: W_new = [ 0.00320562 -0.00056997], MSE = 0.0
# [1.  0.5] 2100 0.0101
# Iteration #0: W_new = [0.94956963 0.26789199], MSE = 8.234
# Iteration #210: W_new = [ 0.15232959 -0.02704524], MSE = 0.011
# Iteration #420: W_new = [ 0.03361454 -0.0055181 ], MSE = 0.0
# Iteration #630: W_new = [ 0.01070547 -0.00136389], MSE = 0.0
# Iteration #840: W_new = [ 0.00560615 -0.00043921], MSE = 0.0
# Iteration #1050: W_new = [ 0.00431418 -0.00020493], MSE = 0.0
# Iteration #1260: W_new = [ 0.00394605 -0.00013817], MSE = 0.0
# Iteration #1470: W_new = [ 0.00382936 -0.00011702], MSE = 0.0
# Iteration #1680: W_new = [ 0.00378862 -0.00010963], MSE = 0.0
# Iteration #1890: W_new = [ 0.00377309 -0.00010681], MSE = 0.0
# [1.  0.5] 2100 0.0151
# Iteration #0: W_new = [0.92470616 0.15326844], MSE = 8.218
# Iteration #210: W_new = [ 0.06855371 -0.01128772], MSE = 0.002
# Iteration #420: W_new = [ 0.01297083 -0.00120862], MSE = 0.0
# Iteration #630: W_new = [ 0.00806984 -0.0003199 ], MSE = 0.0
# Iteration #840: W_new = [ 0.00753353 -0.00022265], MSE = 0.0
# Iteration #1050: W_new = [ 0.00746215 -0.00020971], MSE = 0.0
# Iteration #1260: W_new = [ 0.00745081 -0.00020765], MSE = 0.0
# Iteration #1470: W_new = [ 0.00744869 -0.00020727], MSE = 0.0
# Iteration #1680: W_new = [ 0.00744823 -0.00020718], MSE = 0.0
# Iteration #1890: W_new = [ 0.00744812 -0.00020716], MSE = 0.0
# [1.  0.5] 2100 0.0201
# Iteration #0: W_new = [0.89991029 0.03883126], MSE = 8.202
# Iteration #210: W_new = [ 0.03617392 -0.00485008], MSE = 0.0
# Iteration #420: W_new = [ 0.01215    -0.00049372], MSE = 0.0
# Iteration #630: W_new = [ 0.01119039 -0.00031971], MSE = 0.0
# Iteration #840: W_new = [ 0.01113915 -0.00031041], MSE = 0.0
# Iteration #1050: W_new = [ 0.01113559 -0.00030977], MSE = 0.0
# Iteration #1260: W_new = [ 0.01113528 -0.00030971], MSE = 0.0
# Iteration #1470: W_new = [ 0.01113525 -0.00030971], MSE = 0.0
# Iteration #1680: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #1890: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# [1.  0.5] 2100 0.0251
# Iteration #0: W_new = [ 0.875182   -0.07541956], MSE = 8.186
# Iteration #210: W_new = [ 0.02504365 -0.00226572], MSE = 0.0
# Iteration #420: W_new = [ 0.01500759 -0.00044584], MSE = 0.0
# Iteration #630: W_new = [ 0.01482725 -0.00041313], MSE = 0.0
# Iteration #840: W_new = [ 0.01482258 -0.00041229], MSE = 0.0
# Iteration #1050: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #1260: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #1470: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #1680: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #1890: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# [1.  0.5] 2100 0.0301
# Iteration #0: W_new = [ 0.8505213  -0.18948403], MSE = 8.17
# Iteration #210: W_new = [ 0.02266623 -0.00126855], MSE = 0.0
# Iteration #420: W_new = [ 0.01854313 -0.00052089], MSE = 0.0
# Iteration #630: W_new = [ 0.01850999 -0.00051488], MSE = 0.0
# Iteration #840: W_new = [ 0.01850958 -0.00051481], MSE = 0.0
# Iteration #1050: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #1260: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #1470: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #1680: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #1890: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# [1.  0.5] 2100 0.0351
# Iteration #0: W_new = [ 0.8259282  -0.30336212], MSE = 8.154
# Iteration #210: W_new = [ 0.02388065 -0.00092271], MSE = 0.0
# Iteration #420: W_new = [ 0.02220278 -0.00061845], MSE = 0.0
# Iteration #630: W_new = [ 0.02219677 -0.00061737], MSE = 0.0
# Iteration #840: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #1050: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #1260: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #1470: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #1680: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #1890: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# [1.  0.5] 2100 0.0401
# Iteration #0: W_new = [ 0.80140268 -0.41705386], MSE = 8.138
# Iteration #210: W_new = [ 0.02656344 -0.00084313], MSE = 0.0
# Iteration #420: W_new = [ 0.02588498 -0.00072011], MSE = 0.0
# Iteration #630: W_new = [ 0.02588391 -0.00071991], MSE = 0.0
# Iteration #840: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #1050: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #1260: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #1470: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #1680: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #1890: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# [1.  0.5] 2100 0.0451
# Iteration #0: W_new = [ 0.77694475 -0.53055923], MSE = 8.122
# Iteration #210: W_new = [ 0.02984423 -0.00087199], MSE = 0.0
# Iteration #420: W_new = [ 0.02957126 -0.0008225 ], MSE = 0.0
# Iteration #630: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #840: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1050: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1260: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1470: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1680: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1890: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# [1.  0.5] 3100 0.0001
# Iteration #0: W_new = [0.9995061  0.49771681], MSE = 8.106
# Iteration #310: W_new = [0.90362615 0.09153013], MSE = 1.393
# Iteration #620: W_new = [ 0.85845977 -0.04883107], MSE = 0.484
# Iteration #930: W_new = [ 0.83151066 -0.10079401], MSE = 0.329
# Iteration #1240: W_new = [ 0.81226006 -0.12085301], MSE = 0.291
# Iteration #1550: W_new = [ 0.79692876 -0.12855585], MSE = 0.275
# Iteration #1860: W_new = [ 0.78399365 -0.13119154], MSE = 0.265
# Iteration #2170: W_new = [ 0.77275433 -0.13166508], MSE = 0.257
# Iteration #2480: W_new = [ 0.76283805 -0.13120337], MSE = 0.251
# Iteration #2790: W_new = [ 0.75401558 -0.13035034], MSE = 0.245
# [1.  0.5] 3100 0.0051
# Iteration #0: W_new = [0.97450069 0.3827019 ], MSE = 8.25
# Iteration #310: W_new = [ 0.2356544  -0.04272097], MSE = 0.026
# Iteration #620: W_new = [ 0.07146227 -0.01294726], MSE = 0.002
# Iteration #930: W_new = [ 0.02419152 -0.00437544], MSE = 0.0
# Iteration #1240: W_new = [ 0.00906787 -0.001633  ], MSE = 0.0
# Iteration #1550: W_new = [ 0.00374302 -0.00066742], MSE = 0.0
# Iteration #1860: W_new = [ 0.00169797 -0.00029658], MSE = 0.0
# Iteration #2170: W_new = [ 0.00084808 -0.00014246], MSE = 0.0
# Iteration #2480: W_new = [ 4.68642829e-04 -7.36599637e-05], MSE = 0.0
# Iteration #2790: W_new = [ 2.87863611e-04 -4.08784397e-05], MSE = 0.0
# [1.  0.5] 3100 0.0101
# Iteration #0: W_new = [0.94956963 0.26789199], MSE = 8.234
# Iteration #310: W_new = [ 0.06784183 -0.01172469], MSE = 0.002
# Iteration #620: W_new = [ 0.00975782 -0.00119205], MSE = 0.0
# Iteration #930: W_new = [ 0.0044575  -0.00023092], MSE = 0.0
# Iteration #1240: W_new = [ 0.00385938 -0.00012246], MSE = 0.0
# Iteration #1550: W_new = [ 0.00377755 -0.00010762], MSE = 0.0
# Iteration #1860: W_new = [ 0.00376421 -0.0001052 ], MSE = 0.0
# Iteration #2170: W_new = [ 0.00376167 -0.00010474], MSE = 0.0
# Iteration #2480: W_new = [ 0.00376111 -0.00010464], MSE = 0.0
# Iteration #2790: W_new = [ 0.00376097 -0.00010461], MSE = 0.0
# [1.  0.5] 3100 0.0151
# Iteration #0: W_new = [0.92470616 0.15326844], MSE = 8.218
# Iteration #310: W_new = [ 0.02478406 -0.00335077], MSE = 0.0
# Iteration #620: W_new = [ 0.00794686 -0.0002976 ], MSE = 0.0
# Iteration #930: W_new = [ 0.00746792 -0.00021075], MSE = 0.0
# Iteration #1240: W_new = [ 0.00744913 -0.00020735], MSE = 0.0
# Iteration #1550: W_new = [ 0.00744815 -0.00020717], MSE = 0.0
# Iteration #1860: W_new = [ 0.00744808 -0.00020715], MSE = 0.0
# Iteration #2170: W_new = [ 0.00744808 -0.00020715], MSE = 0.0
# Iteration #2480: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# Iteration #2790: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# [1.  0.5] 3100 0.0201
# Iteration #0: W_new = [0.89991029 0.03883126], MSE = 8.202
# Iteration #310: W_new = [ 0.01579946 -0.00115549], MSE = 0.0
# Iteration #620: W_new = [ 0.01117631 -0.00031715], MSE = 0.0
# Iteration #930: W_new = [ 0.0111358  -0.00030981], MSE = 0.0
# Iteration #1240: W_new = [ 0.01113525 -0.00030971], MSE = 0.0
# Iteration #1550: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #1860: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #2170: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #2480: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #2790: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# [1.  0.5] 3100 0.0251
# Iteration #0: W_new = [ 0.875182   -0.07541956], MSE = 8.186
# Iteration #310: W_new = [ 0.01607037 -0.00063855], MSE = 0.0
# Iteration #620: W_new = [ 0.01482575 -0.00041286], MSE = 0.0
# Iteration #930: W_new = [ 0.01482242 -0.00041226], MSE = 0.0
# Iteration #1240: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #1550: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #1860: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #2170: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #2480: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #2790: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# [1.  0.5] 3100 0.0301
# Iteration #0: W_new = [ 0.8505213  -0.18948403], MSE = 8.17
# Iteration #310: W_new = [ 0.01884161 -0.00057502], MSE = 0.0
# Iteration #620: W_new = [ 0.01850984 -0.00051486], MSE = 0.0
# Iteration #930: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #1240: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #1550: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #1860: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #2170: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #2480: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #2790: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# [1.  0.5] 3100 0.0351
# Iteration #0: W_new = [ 0.8259282  -0.30336212], MSE = 8.154
# Iteration #310: W_new = [ 0.02228459 -0.00063329], MSE = 0.0
# Iteration #620: W_new = [ 0.02219676 -0.00061736], MSE = 0.0
# Iteration #930: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #1240: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #1550: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #1860: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #2170: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #2480: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #2790: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# [1.  0.5] 3100 0.0401
# Iteration #0: W_new = [ 0.80140268 -0.41705386], MSE = 8.138
# Iteration #310: W_new = [ 0.02590701 -0.0007241 ], MSE = 0.0
# Iteration #620: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #930: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #1240: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #1550: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #1860: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #2170: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #2480: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #2790: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# [1.  0.5] 3100 0.0451
# Iteration #0: W_new = [ 0.77694475 -0.53055923], MSE = 8.122
# Iteration #310: W_new = [ 0.02957711 -0.00082356], MSE = 0.0
# Iteration #620: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #930: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1240: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1550: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1860: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #2170: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #2480: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #2790: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# [1.  0.5] 4100 0.0001
# Iteration #0: W_new = [0.9995061  0.49771681], MSE = 8.106
# Iteration #410: W_new = [0.88478559 0.02649875], MSE = 0.882
# Iteration #820: W_new = [ 0.83762647 -0.09150316], MSE = 0.35
# Iteration #1230: W_new = [ 0.80919504 -0.12289845], MSE = 0.287
# Iteration #1640: W_new = [ 0.78765273 -0.13071941], MSE = 0.268
# Iteration #2050: W_new = [ 0.76964047 -0.13159274], MSE = 0.255
# Iteration #2460: W_new = [ 0.75399115 -0.13034846], MSE = 0.245
# Iteration #2870: W_new = [ 0.74018109 -0.1285078 ], MSE = 0.235
# Iteration #3280: W_new = [ 0.72790628 -0.12657875], MSE = 0.227
# Iteration #3690: W_new = [ 0.7169534  -0.12473426], MSE = 0.22
# [1.  0.5] 4100 0.0051
# Iteration #0: W_new = [0.97450069 0.3827019 ], MSE = 8.25
# Iteration #410: W_new = [ 0.15428508 -0.0279659 ], MSE = 0.011
# Iteration #820: W_new = [ 0.03186762 -0.00576738], MSE = 0.0
# Iteration #1230: W_new = [ 0.00764247 -0.00137452], MSE = 0.0
# Iteration #1640: W_new = [ 0.00212707 -0.00037439], MSE = 0.0
# Iteration #2050: W_new = [ 0.00070104 -0.0001158 ], MSE = 0.0
# Iteration #2460: W_new = [ 2.87228417e-04 -4.07632571e-05], MSE = 0.0
# Iteration #2870: W_new = [ 1.53886669e-04 -1.65837871e-05], MSE = 0.0
# Iteration #3280: W_new = [ 1.06635394e-04 -8.01549674e-06], MSE = 0.0
# Iteration #3690: W_new = [ 8.83823120e-05 -4.70558182e-06], MSE = 0.0
# [1.  0.5] 4100 0.0101
# Iteration #0: W_new = [0.94956963 0.26789199], MSE = 8.234
# Iteration #410: W_new = [ 0.03140041 -0.0051166 ], MSE = 0.0
# Iteration #820: W_new = [ 0.00496555 -0.00032305], MSE = 0.0
# Iteration #1230: W_new = [ 0.00383078 -0.00011727], MSE = 0.0
# Iteration #1640: W_new = [ 0.00376616 -0.00010556], MSE = 0.0
# Iteration #2050: W_new = [ 0.00376141 -0.00010469], MSE = 0.0
# Iteration #2460: W_new = [ 0.00376097 -0.00010461], MSE = 0.0
# Iteration #2870: W_new = [ 0.00376092 -0.0001046 ], MSE = 0.0
# Iteration #3280: W_new = [ 0.00376091 -0.0001046 ], MSE = 0.0
# Iteration #3690: W_new = [ 0.00376091 -0.0001046 ], MSE = 0.0
# [1.  0.5] 4100 0.0151
# Iteration #0: W_new = [0.92470616 0.15326844], MSE = 8.218
# Iteration #410: W_new = [ 0.01236639 -0.00109901], MSE = 0.0
# Iteration #820: W_new = [ 0.00749312 -0.00021532], MSE = 0.0
# Iteration #1230: W_new = [ 0.00744871 -0.00020727], MSE = 0.0
# Iteration #1640: W_new = [ 0.00744809 -0.00020716], MSE = 0.0
# Iteration #2050: W_new = [ 0.00744808 -0.00020715], MSE = 0.0
# Iteration #2460: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# Iteration #2870: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# Iteration #3280: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# Iteration #3690: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# [1.  0.5] 4100 0.0201
# Iteration #0: W_new = [0.89991029 0.03883126], MSE = 8.202
# Iteration #410: W_new = [ 0.01200409 -0.00046726], MSE = 0.0
# Iteration #820: W_new = [ 0.0111369  -0.00031001], MSE = 0.0
# Iteration #1230: W_new = [ 0.01113525 -0.00030971], MSE = 0.0
# Iteration #1640: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #2050: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #2460: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #2870: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #3280: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #3690: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# [1.  0.5] 4100 0.0251
# Iteration #0: W_new = [ 0.875182   -0.07541956], MSE = 8.186
# Iteration #410: W_new = [ 0.01497478 -0.00043989], MSE = 0.0
# Iteration #820: W_new = [ 0.01482247 -0.00041227], MSE = 0.0
# Iteration #1230: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #1640: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #2050: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #2460: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #2870: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #3280: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #3690: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# [1.  0.5] 4100 0.0301
# Iteration #0: W_new = [ 0.8505213  -0.18948403], MSE = 8.17
# Iteration #410: W_new = [ 0.0185361  -0.00051962], MSE = 0.0
# Iteration #820: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #1230: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #1640: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #2050: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #2460: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #2870: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #3280: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #3690: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# [1.  0.5] 4100 0.0351
# Iteration #0: W_new = [ 0.8259282  -0.30336212], MSE = 8.154
# Iteration #410: W_new = [ 0.02220132 -0.00061819], MSE = 0.0
# Iteration #820: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #1230: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #1640: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #2050: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #2460: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #2870: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #3280: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #3690: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# [1.  0.5] 4100 0.0401
# Iteration #0: W_new = [ 0.80140268 -0.41705386], MSE = 8.138
# Iteration #410: W_new = [ 0.02588469 -0.00072005], MSE = 0.0
# Iteration #820: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #1230: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #1640: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #2050: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #2460: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #2870: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #3280: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #3690: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# [1.  0.5] 4100 0.0451
# Iteration #0: W_new = [ 0.77694475 -0.53055923], MSE = 8.122
# Iteration #410: W_new = [ 0.0295712  -0.00082249], MSE = 0.0
# Iteration #820: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1230: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1640: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #2050: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #2460: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #2870: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #3280: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #3690: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# [1.  0.5] 5100 0.0001
# Iteration #0: W_new = [0.9995061  0.49771681], MSE = 8.106
# Iteration #510: W_new = [ 0.86928776 -0.02041955], MSE = 0.61
# Iteration #1020: W_new = [ 0.82071571 -0.11367785], MSE = 0.304
# Iteration #1530: W_new = [ 0.78995198 -0.13032277], MSE = 0.27
# Iteration #2040: W_new = [ 0.7653646  -0.13138195], MSE = 0.252
# Iteration #2550: W_new = [ 0.74426368 -0.12909892], MSE = 0.238
# Iteration #3060: W_new = [ 0.72575798 -0.12622413], MSE = 0.226
# Iteration #3570: W_new = [ 0.70939695 -0.12342264], MSE = 0.215
# Iteration #4080: W_new = [ 0.6948733  -0.12085113], MSE = 0.206
# Iteration #4590: W_new = [ 0.68194598 -0.11853227], MSE = 0.198
# [1.  0.5] 5100 0.0051
# Iteration #0: W_new = [0.97450069 0.3827019 ], MSE = 8.25
# Iteration #510: W_new = [ 0.10102064 -0.01830721], MSE = 0.005
# Iteration #1020: W_new = [ 0.01423359 -0.00256972], MSE = 0.0
# Iteration #1530: W_new = [ 0.00244899 -0.00043277], MSE = 0.0
# Iteration #2040: W_new = [ 5.42510332e-04 -8.70546965e-05], MSE = 0.0
# Iteration #2550: W_new = [ 1.80985758e-04 -2.14977890e-05], MSE = 0.0
# Iteration #3060: W_new = [ 1.01803365e-04 -7.13928293e-06], MSE = 0.0
# Iteration #3570: W_new = [ 8.20381518e-05 -3.55516619e-06], MSE = 0.0
# Iteration #4080: W_new = [ 7.64829700e-05 -2.54781961e-06], MSE = 0.0
# Iteration #4590: W_new = [ 7.47441543e-05 -2.23251219e-06], MSE = 0.0
# [1.  0.5] 5100 0.0101
# Iteration #0: W_new = [0.94956963 0.26789199], MSE = 8.234
# Iteration #510: W_new = [ 0.01568243 -0.00226639], MSE = 0.0
# Iteration #1020: W_new = [ 0.00400289 -0.00014848], MSE = 0.0
# Iteration #1530: W_new = [ 0.00376792 -0.00010587], MSE = 0.0
# Iteration #2040: W_new = [ 0.00376119 -0.00010465], MSE = 0.0
# Iteration #2550: W_new = [ 0.00376092 -0.00010461], MSE = 0.0
# Iteration #3060: W_new = [ 0.00376091 -0.0001046 ], MSE = 0.0
# Iteration #3570: W_new = [ 0.00376091 -0.0001046 ], MSE = 0.0
# Iteration #4080: W_new = [ 0.00376091 -0.0001046 ], MSE = 0.0
# Iteration #4590: W_new = [ 0.00376091 -0.0001046 ], MSE = 0.0
# [1.  0.5] 5100 0.0151
# Iteration #0: W_new = [0.92470616 0.15326844], MSE = 8.218
# Iteration #510: W_new = [ 0.00884343 -0.00046018], MSE = 0.0
# Iteration #1020: W_new = [ 0.00745214 -0.00020789], MSE = 0.0
# Iteration #1530: W_new = [ 0.00744809 -0.00020716], MSE = 0.0
# Iteration #2040: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# Iteration #2550: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# Iteration #3060: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# Iteration #3570: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# Iteration #4080: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# Iteration #4590: W_new = [ 0.00744807 -0.00020715], MSE = 0.0
# [1.  0.5] 5100 0.0201
# Iteration #0: W_new = [0.89991029 0.03883126], MSE = 8.202
# Iteration #510: W_new = [ 0.01129709 -0.00033905], MSE = 0.0
# Iteration #1020: W_new = [ 0.01113531 -0.00030972], MSE = 0.0
# Iteration #1530: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #2040: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #2550: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #3060: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #3570: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #4080: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# Iteration #4590: W_new = [ 0.01113524 -0.0003097 ], MSE = 0.0
# [1.  0.5] 5100 0.0251
# Iteration #0: W_new = [ 0.875182   -0.07541956], MSE = 8.186
# Iteration #510: W_new = [ 0.01484101 -0.00041563], MSE = 0.0
# Iteration #1020: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #1530: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #2040: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #2550: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #3060: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #3570: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #4080: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# Iteration #4590: W_new = [ 0.01482241 -0.00041226], MSE = 0.0
# [1.  0.5] 5100 0.0301
# Iteration #0: W_new = [ 0.8505213  -0.18948403], MSE = 8.17
# Iteration #510: W_new = [ 0.01851169 -0.00051519], MSE = 0.0
# Iteration #1020: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #1530: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #2040: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #2550: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #3060: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #3570: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #4080: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# Iteration #4590: W_new = [ 0.01850957 -0.00051481], MSE = 0.0
# [1.  0.5] 5100 0.0351
# Iteration #0: W_new = [ 0.8259282  -0.30336212], MSE = 8.154
# Iteration #510: W_new = [ 0.02219698 -0.0006174 ], MSE = 0.0
# Iteration #1020: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #1530: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #2040: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #2550: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #3060: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #3570: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #4080: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# Iteration #4590: W_new = [ 0.02219674 -0.00061736], MSE = 0.0
# [1.  0.5] 5100 0.0401
# Iteration #0: W_new = [ 0.80140268 -0.41705386], MSE = 8.138
# Iteration #510: W_new = [ 0.02588393 -0.00071991], MSE = 0.0
# Iteration #1020: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #1530: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #2040: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #2550: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #3060: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #3570: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #4080: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# Iteration #4590: W_new = [ 0.0258839  -0.00071991], MSE = 0.0
# [1.  0.5] 5100 0.0451
# Iteration #0: W_new = [ 0.77694475 -0.53055923], MSE = 8.122
# Iteration #510: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1020: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #1530: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #2040: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #2550: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #3060: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #3570: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #4080: W_new = [ 0.02957107 -0.00082246], MSE = 0.0
# Iteration #4590: W_new = [ 0.02957107 -0.00082246], MSE = 0.0

# %% [markdown]
# **Из полученных результатов и графиков выбираю вариант с кол-вом итераций 2100 и скорость обучения 0,0001**
#
# при необходимости можно построить больше графиков и выбрать наилучший

# %% [markdown]
# ---

# %% [markdown]
# 2. В этом коде мы избавляемся от итераций по весам, но здесь есть ошибка, исправьте её. (код в материалах к уроку)

# %%
n = X.shape[0]

eta = 1e-2 
n_iter = 100

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
#     for k in range(W.shape[0]):
#         W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    # ИЗМЕНЕНИЯ
    # было:  W -= eta * (1/n * 2 * np.dot(X, y_pred - y))
   
    # заменил X -> X.T, стало:
    W -= eta * (1/n * 2 * np.dot(X.T, y_pred - y))
    # ИЗМЕНЕНИЯ
    #
    
    if i % 10 == 0:
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [0.95060966 0.27168099], MSE = 8.11
# Iteration #10: W_new = [ 0.80100585 -0.13431421], MSE = 0.28
# Iteration #20: W_new = [ 0.73287226 -0.1277118 ], MSE = 0.23
# Iteration #30: W_new = [ 0.67161159 -0.11667952], MSE = 0.2
# Iteration #40: W_new = [ 0.61572611 -0.10654657], MSE = 0.16
# Iteration #50: W_new = [ 0.56473335 -0.09729983], MSE = 0.14
# Iteration #60: W_new = [ 0.5182048  -0.08886259], MSE = 0.11
# Iteration #70: W_new = [ 0.47574964 -0.08116401], MSE = 0.09
# Iteration #80: W_new = [ 0.43701127 -0.0741394 ], MSE = 0.08
# Iteration #90: W_new = [ 0.40166428 -0.06772977], MSE = 0.07

# %% [markdown]
# ---

# %% [markdown]
# 3. Вместо того чтобы задавать количество итераций, задайте условие остановки алгоритма, когда ошибка за итерацию начинает изменяться ниже определённого порога — упрощённый аналог параметра tol в линейной регрессии в sklearn.

# %%
n = X.shape[0]

eta = 1e-2 
n_iter = 100

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
#     for k in range(W.shape[0]):
#         W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    # ИЗМЕНЕНИЯ
    # было:  W -= eta * (1/n * 2 * np.dot(X, y_pred - y))
   
    # заменил X -> X.T, стало:
    W -= eta * (1/n * 2 * np.dot(X.T, y_pred - y))
    # ИЗМЕНЕНИЯ
    #
    
    
    
    if i % 10 == 0:
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 7.0011236 10.6169007], MSE = 738.65
# Iteration #20: W_new = [10.3486292  10.10603105], MSE = 622.03
# Iteration #30: W_new = [13.38789582  9.55618391], MSE = 525.24
# Iteration #40: W_new = [16.16088505  9.05336203], MSE = 444.66
# Iteration #50: W_new = [18.69110735  8.59454545], MSE = 377.58
# Iteration #60: W_new = [20.99981865  8.17589626], MSE = 321.72
# Iteration #70: W_new = [23.10641138  7.79389815], MSE = 275.22
# Iteration #80: W_new = [25.02858024  7.44534246], MSE = 236.5
# Iteration #90: W_new = [26.78247081  7.12730145], MSE = 204.27
